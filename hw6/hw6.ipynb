# %% [markdown]
# # Import libraries

# %%
import pandas as pd

# %% [markdown]
# # Load Data

# %%
! wget https://github.com/alexeygrigorev/datasets/raw/refs/heads/master/jamb_exam_results.csv
# Out:
# --2024-11-06 19:44:28--  https://github.com/alexeygrigorev/datasets/raw/refs/heads/master/jamb_exam_results.csv
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/alexeygrigorev/datasets/refs/heads/master/jamb_exam_results.csv [following]
# --2024-11-06 19:44:28--  https://raw.githubusercontent.com/alexeygrigorev/datasets/refs/heads/master/jamb_exam_results.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 391501 (382K) [text/plain]
# Saving to: ‘jamb_exam_results.csv.1’
#
# jamb_exam_results.c 100%[===================>] 382.33K  2.06MB/s    in 0.2s
#
# 2024-11-06 19:44:29 (2.06 MB/s) - ‘jamb_exam_results.csv.1’ saved [391501/391501]

# %%
df = pd.read_csv('jamb_exam_results.csv')

# %%
df.head()
# Out:
#    JAMB_Score  Study_Hours_Per_Week  Attendance_Rate  Teacher_Quality  \
# 0         192                    22               78                4
# 1         207                    14               88                4
# 2         182                    29               87                2
# 3         210                    29               99                2
# 4         199                    12               98                3
#
#    Distance_To_School School_Type School_Location Extra_Tutorials  \
# 0                12.4      Public           Urban             Yes
# 1                 2.7      Public           Rural              No
# 2                 9.6      Public           Rural             Yes
# 3                 2.6      Public           Urban              No
# 4                 8.8      Public           Urban              No
#
#   Access_To_Learning_Materials Parent_Involvement IT_Knowledge  Student_ID  \
# 0                          Yes               High       Medium           1
# 1                          Yes               High         High           2
# 2                          Yes               High       Medium           3
# 3                          Yes             Medium         High           4
# 4                          Yes             Medium       Medium           5
#
#    Age  Gender Socioeconomic_Status Parent_Education_Level  \
# 0   17    Male                  Low               Tertiary
# 1   15    Male                 High                    NaN
# 2   20  Female                 High               Tertiary
# 3   22  Female               Medium               Tertiary
# 4   22  Female               Medium               Tertiary
#
#    Assignments_Completed
# 0                      2
# 1                      1
# 2                      2
# 3                      1
# 4                      1

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#    jamb_score  study_hours_per_week  attendance_rate  teacher_quality  \
# 0         192                    22               78                4
# 1         207                    14               88                4
# 2         182                    29               87                2
# 3         210                    29               99                2
# 4         199                    12               98                3
#
#    distance_to_school school_type school_location extra_tutorials  \
# 0                12.4      Public           Urban             Yes
# 1                 2.7      Public           Rural              No
# 2                 9.6      Public           Rural             Yes
# 3                 2.6      Public           Urban              No
# 4                 8.8      Public           Urban              No
#
#   access_to_learning_materials parent_involvement it_knowledge  student_id  \
# 0                          Yes               High       Medium           1
# 1                          Yes               High         High           2
# 2                          Yes               High       Medium           3
# 3                          Yes             Medium         High           4
# 4                          Yes             Medium       Medium           5
#
#    age  gender socioeconomic_status parent_education_level  \
# 0   17    Male                  Low               Tertiary
# 1   15    Male                 High                    NaN
# 2   20  Female                 High               Tertiary
# 3   22  Female               Medium               Tertiary
# 4   22  Female               Medium               Tertiary
#
#    assignments_completed
# 0                      2
# 1                      1
# 2                      2
# 3                      1
# 4                      1

# %% [markdown]
# ## Remove student_id column

# %%
df.drop('student_id', axis=1, inplace=True)

# %%
df.head()
# Out:
#    jamb_score  study_hours_per_week  attendance_rate  teacher_quality  \
# 0         192                    22               78                4
# 1         207                    14               88                4
# 2         182                    29               87                2
# 3         210                    29               99                2
# 4         199                    12               98                3
#
#    distance_to_school school_type school_location extra_tutorials  \
# 0                12.4      Public           Urban             Yes
# 1                 2.7      Public           Rural              No
# 2                 9.6      Public           Rural             Yes
# 3                 2.6      Public           Urban              No
# 4                 8.8      Public           Urban              No
#
#   access_to_learning_materials parent_involvement it_knowledge  age  gender  \
# 0                          Yes               High       Medium   17    Male
# 1                          Yes               High         High   15    Male
# 2                          Yes               High       Medium   20  Female
# 3                          Yes             Medium         High   22  Female
# 4                          Yes             Medium       Medium   22  Female
#
#   socioeconomic_status parent_education_level  assignments_completed
# 0                  Low               Tertiary                      2
# 1                 High                    NaN                      1
# 2                 High               Tertiary                      2
# 3               Medium               Tertiary                      1
# 4               Medium               Tertiary                      1

# %% [markdown]
# ## Fill Missing values

# %%
df.isnull().sum()
# Out:
# jamb_score                        0
# study_hours_per_week              0
# attendance_rate                   0
# teacher_quality                   0
# distance_to_school                0
# school_type                       0
# school_location                   0
# extra_tutorials                   0
# access_to_learning_materials      0
# parent_involvement                0
# it_knowledge                      0
# age                               0
# gender                            0
# socioeconomic_status              0
# parent_education_level          891
# assignments_completed             0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# jamb_score                        int64
# study_hours_per_week              int64
# attendance_rate                   int64
# teacher_quality                   int64
# distance_to_school              float64
# school_type                      object
# school_location                  object
# extra_tutorials                  object
# access_to_learning_materials     object
# parent_involvement               object
# it_knowledge                     object
# age                               int64
# gender                           object
# socioeconomic_status             object
# parent_education_level           object
# assignments_completed             int64
# dtype: object

# %% [markdown]
# Note: The only column (feature) that has missing values is "parent_education_level" which is a categorical feature. Shouldn't the missing values be replaced with "unknown" instead of zeros?

# %%
df.parent_education_level.unique()
# Out:
# array(['Tertiary', nan, 'Primary', 'Secondary'], dtype=object)

# %% [markdown]
# I'll replace with 0's and test later

# %%
df.fillna(0, inplace=True)

# %% [markdown]
# ## Split the data

# %% [markdown]
# Import split class

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Manually calculate sizes

# %%
print(len(df))
print(len(df)*.6)
print(len(df)*.2)
# Out:
# 5000
# 3000.0
# 1000.0

# %% [markdown]
# Split with train_test_split in two steps and with random_state = 1

# %%
df_train_full, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_train_full, test_size=0.25, random_state=11)

# %% [markdown]
# Check sizes

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (3000, 1000, 1000)

# %% [markdown]
# Reset indexes

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %% [markdown]
# Extract target variable

# %%
y_train = df_train.jamb_score.values
y_val = df_val.jamb_score.values
y_test = df_test.jamb_score.values

del df_train['jamb_score']
del df_val['jamb_score']
del df_test['jamb_score']

# %% [markdown]
# Check sizes again

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (3000, 1000, 1000)

# %%
len(y_train), len(y_val), len(y_test)
# Out:
# (3000, 1000, 1000)

# %% [markdown]
# Import vectorizer and metrics

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.feature_extraction import DictVectorizer
from sklearn.tree import export_text

# %% [markdown]
# Turn dataframes into matrices

# %%
# Define Vectorizer
dv = DictVectorizer(sparse=True)

# train
train_dicts = df_train.to_dict(orient='records')    # Transform data frame to dictionary
X_train = dv.fit_transform(train_dicts)             # Transform dictionary to matrix

# validation
val_dicts = df_val.to_dict(orient='records')
X_val = dv.transform(val_dicts)

# test
test_dicts = df_test.to_dict(orient='records')
X_test = dv.transform(test_dicts)

# %% [markdown]
# # Question 1

# %% [markdown]
# Let's train a decision tree regressor to predict the jamb_score variable.
#
# Train a model with max_depth=1

# %%
dt = DecisionTreeRegressor(max_depth=1)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
print(export_text(dt, feature_names=list(dv.get_feature_names_out())))
# Out:
# |--- study_hours_per_week <= 18.50
# |   |--- value: [156.03]
# |--- study_hours_per_week >  18.50
# |   |--- value: [188.86]

# %% [markdown]
# Which feature is used for splitting the data?
#
# * study_hours_per_week
# * attendance_rate
# * teacher_quality
# * distance_to_school

# %% [markdown]
# **Answer = study_hours_per_week**

# %% [markdown]
# # Question 2

# %% [markdown]
# Train a random forest regressor with these parameters:
#
# * n_estimators=10
# * random_state=1
# * n_jobs=-1 (optional - to make training faster)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import root_mean_squared_error

# %%
rf = RandomForestRegressor(n_estimators=10, random_state=1,n_jobs=-1)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, n_jobs=-1, random_state=1)

# %%
y_pred = rf.predict(X_val)

# %%
y_pred
# Out:
# array([133.1, 257.1, 168.8, 115.2, 200.7, 166.2, 162.6, 154.8, 175.7,
#        137.6, 153. , 183.2, 173.7, 178.6, 148. , 152.1, 140.9, 131.1,
#        182.5, 166.5, 183.7, 160.2, 154.7, 168.1, 189.4, 163.8, 165.2,
#        172.3, 177.7, 185.5, 164.2, 144.9, 139. , 210.4, 150.4, 236.2,
#        178.4, 161.8, 132.4, 149.2, 163. , 198.6, 238.2, 147.2, 170.4,
#        205.7, 167.1, 216.8, 156.9, 169.1, 164.9, 177.5, 151.7, 179.1,
#        186.2, 155.9, 183.6, 119.3, 174.6, 160.2, 137.3, 173.7, 141.9,
#        205. , 201.5, 201.6, 217.3, 193.2, 194. , 111.1, 179.4, 170.4,
#        206.7, 156.3, 212.1, 171.8, 152.8, 148. , 144.1, 190.9, 203.9,
#        173.6, 141.3, 144.3, 182.6, 154.1, 233.2, 136.1, 174.4, 172.6,
#        218.9, 208.2, 188.5, 144.6, 159.5, 173.7, 139.1, 145.6, 145. ,
#        199.5, 168.3, 141.2, 246. , 175.9, 201. , 135.3, 187.5, 210. ,
#        186.1, 189.8, 226.4, 200. , 155.9, 145.8, 165. , 172.4, 211.9,
#        175.4, 206.6, 177.9, 171.7, 172.8, 208.6, 223. , 178. , 187.7,
#        175.5, 205.4, 139.9, 179. , 192.9, 159.5, 239.5, 196.5, 221.1,
#        149.1, 218.4, 178.1, 162.5, 154.5, 147.6, 158.9, 202.5, 183. ,
#        117.6, 155.2, 150.2, 126.7, 200.2, 195. , 185.2, 178.1, 157.1,
#        136.9, 207.5, 170.4, 186.5, 149. , 194.8, 146.6, 148. , 158.9,
#        133.1, 163. , 148.7, 147. , 168.4, 190.1, 182.8, 138.2, 223.1,
#        156. , 151.1, 162.2, 213.2, 142.2, 157.5, 199.3, 140.5, 176.7,
#        190.7, 216.2, 192.5, 177.9, 162. , 174. , 131.6, 165.1, 149.3,
#        214.8, 164.3, 153. , 186.5, 175.5, 258.7, 206.5, 149.8, 130.6,
#        212.1, 124.3, 225.2, 127.8, 157. , 186.2, 213. , 195.2, 165.1,
#        159. , 128.1, 138.4, 172.7, 184.6, 194.8, 187.7, 174.5, 142.1,
#        174.6, 160.1, 150.3, 214.3, 186.1, 211.8, 199.7, 164.3, 140.4,
#        214. , 161.1, 214.5, 181.3, 157.7, 175.1, 160.6, 132.4, 138.5,
#        220.1, 141.1, 155.5, 184.6, 179. , 160.3, 169.7, 183.2, 152.5,
#        201.6, 180. , 156.7, 170.9, 189.8, 173.3, 174.1, 192.3, 139. ,
#        175.1, 185.7, 170.5, 146.2, 189.7, 176.6, 182.9, 149.1, 187.6,
#        142. , 199.1, 176.8, 253.1, 150.8, 159.5, 251.3, 238.9, 162.4,
#        180.9, 160.9, 206.1, 227.8, 183.5, 140.4, 197. , 147.6, 151.4,
#        173.7, 195.3, 167.5, 222.9, 195.1, 208.1, 160.4, 240.9, 181.5,
#        137.4, 205. , 152.3, 162.8, 186.2, 131.5, 223.2, 187.1, 145.3,
#        150.1, 199.9, 178.7, 177.6, 161.7, 198.6, 203.3, 134.3, 152.7,
#        209.3, 136.3, 179. , 164.6, 186.5, 174.5, 173.6, 198.5, 181.6,
#        277. , 169.5, 149.9, 154.1, 146.2, 226.9, 146.3, 168.6, 179.6,
#        186.3, 165.5, 256. , 196.3, 135.1, 166.7, 182.3, 205.6, 151. ,
#        179. , 181.3, 182.4, 160.2, 156.8, 190.8, 173.1, 206.3, 186.3,
#        186.2, 185.9, 190. , 196.1, 187.3, 166.9, 185.6, 219.1, 136.4,
#        162.3, 205.3, 166.3, 209.2, 192. , 154.4, 179.7, 143.2, 187.2,
#        171.1, 130.7, 142.3, 174. , 128.7, 183.9, 135.5, 138.5, 125. ,
#        140.3, 140.2, 210.4, 127.8, 189.3, 156.9, 181.8, 214.8, 192.7,
#        180.3, 138.2, 173.1, 149.7, 169.4, 182.2, 154.7, 171.4, 151.6,
#        163. , 159.6, 153.1, 122.2, 231.3, 131.6, 139.8, 171.7, 194.3,
#        204.7])

# %%
y_pred.shape
# Out:
# (1000,)

# %% [markdown]
# Calculate RMSE

# %%
rmse = root_mean_squared_error(y_val, y_pred)
print("RMSE:", rmse)
# Out:
# RMSE: 42.59861500095983

# %% [markdown]
# What's the RMSE of this model on the validation data?
#
# * 22.13
# * 42.13
# * 62.13
# * 82.12

# %% [markdown]
# **Answer = 42.13**
